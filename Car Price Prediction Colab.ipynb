# %% [markdown]
# <a href="https://colab.research.google.com/github/nehamishra2002033/Car-Price-Prediction---Python/blob/main/Car%20Price%20Prediction%20Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Steps/ Approach to perfrom EDA - (Exploratory Data Analysis) Data Loading and Initial Inspection Data Cleaning. ( detect outliers using IQR and perfrom capping of outliers) Data Exploration: Statistical Summary
#
# Distribution Analysis
#
# Correlation Analysis
#
# Visual Analysis:
#
# Univariate Analysis: Plot histograms, boxplots, or density plots for numerical features to understand their distribution.
#
# Bivariate Analysis: Examine relationships between features and the target variable using scatter plots, bar plots, or boxplots.
#
# Multivariate Analysis: Investigate relationships between multiple features and the target variable using pair plots, heatmaps, or other multivariate visualizations.
#
# Problem Statement
#
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
#
# https://www.kaggle.com/datasets/hellbuoy/car-price-prediction

# %%
# EDA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings # Suppress warning
warnings.filterwarnings("ignore")

pd.set_option('display.max_rows', None) # Show all rows
pd.set_option('display.max_columns', None) # Show all columns

# %%
# Upload the data
from google.colab import files
uploaded = files.upload()
print(uploaded)
# Out:
#      <input type="file" id="files-246e99b7-d6af-4778-b42d-4142dd2aa229" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-246e99b7-d6af-4778-b42d-4142dd2aa229">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("car_price_assignment.csv") # Read the csv

df.head()

# %%
df.tail()

# %%
# Size of the data

df.shape

# %%
# How many columns datatypes have null values

df.info()

# %%
df.columns

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace = True)

# %%
# remove unnessary columns in the data

df.head()

# %%
df.drop(columns = 'car_ID', inplace = True)

# %%
df.head()

# %%
df['symboling'].unique()

# %%
df['CarName'].unique()

# %%
df['CarName'].nunique()

# %%
df['CarName'][0].split()[0]

# %%
car_name = [i.split()[0] for i in df['CarName']]

car_name

# %%
df.head(1)

# %%
df.drop(columns = 'CarName', inplace = True)

df.head(1)

# %%
# Insert the new columns which is car_name to the df

df.insert(loc = 0, column = 'CarName', value = car_name)

df.head()

# %%
df['CarName'].nunique()

# %%
df['CarName'].value_counts()

# %%
# Function for replacing wrong value with the correct one

def change(a, b):
    df['CarName'].replace(a, b, inplace = True)

# %%
change('toyouta', 'toyota')
change('vw', 'volkswagen')
change('vokswagen', 'volkswagen')
change('Nissan', 'nissan')
change('maxda', 'mazda')
change('porcshce', 'porsche')

# %%
df['CarName'].nunique()

# %%
df.head(1)

# %%
df['fueltype'].unique()

# %%
df['carbody'].unique()

# %%
print(df.shape)

df.drop_duplicates(inplace = True)

print(df.shape)

# %%
# Selecting the numeric df

num_df = df.select_dtypes(include = np.number)

num_df.head(1)

# %%
cat_df = df.select_dtypes(include = ['category', 'O'])

cat_df.head(5)

# %%
# Statistics for numeric values

num_df.describe()

# %%
# Statistics for categorical values

cat_df.describe()

# %%
# Visulization

# Univariate
# Bivariate
# Multivariate

# %%
# Univariate ANalysis

# %%
# Box Plot

# Matplotlib

plt.figure(figsize = (6, 4))
plt.boxplot(df['price'])
plt.show()

# %%
# Seaborn BoxPlot

plt.figure(figsize = (8, 4))
sns.boxplot(x = df['price'])
plt.show()

# %%
plt.figure(figsize = (8, 4))
plt.title("Price BoxPlot")
sns.boxplot(x = df['price'])
plt.show()

# %%
num_df.shape

# %%
for i in num_df.columns:
    plt.figure(figsize = (4, 2))
    plt.title(f"{i} BoxPlot")
    sns.boxplot(x = df[i])
    plt.show()

# %%
# Histogram

for i in num_df.columns:
    plt.figure(figsize = (4, 2))
    plt.title(f"{i} Histogram")
    sns.histplot(x = df[i], kde = True)
    plt.show()

# %%
# Categorical Variable

# Count plot

df['fueltype'].value_counts()

# %%
plt.figure(figsize = (6, 4))
sns.countplot(x = df['fueltype'])
plt.show()

# %%
# Pie Chart

cat_df.head()

# %%
cat_df['doornumber'].value_counts()

# %%
plt.pie(cat_df['doornumber'].value_counts())
plt.show()

# %%
plt.pie(cat_df['doornumber'].value_counts(), autopct = '%1.1f%%', labels = cat_df['doornumber'].value_counts().index)
plt.show()

# %%
# Bivariate Analysis

# Scatter plot

plt.figure(figsize = (6,4))
sns.scatterplot(x = num_df['horsepower'], y = df['price'])
plt.show()

# %%
# Boxplot for price against doornumber

plt.figure(figsize = (20, 10))
sns.boxplot(x = cat_df['doornumber'], y = df['price'])
plt.show()

# %%
# Multivariate analysis

num_df.corr()

# %%
# Heatmap

plt.figure(figsize = (20, 10))
sns.heatmap(num_df.corr(), annot = True)
plt.show()
